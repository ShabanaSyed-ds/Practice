# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sn
mydata=pd.read_csv("/Users/zoyasyed/Downloads/DataScienceEssential_Module3/IU4/Automobile_price_data__Raw_.csv")

# %%
mydata.describe()
# Out:
#         symboling  wheel-base      length       width      height  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000
# mean     0.834146   98.756585  174.049268   65.907805   53.724878
# std      1.245307    6.021776   12.337289    2.145204    2.443522
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.100000   52.000000
# 50%      1.000000   97.000000  173.200000   65.500000   54.100000
# 75%      2.000000  102.400000  183.100000   66.900000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#        curb-weight  engine-size  compression-ratio    city-mpg  highway-mpg
# count   205.000000   205.000000         205.000000  205.000000   205.000000
# mean   2555.565854   126.907317          10.142537   25.219512    30.751220
# std     520.680204    41.642693           3.972040    6.542142     6.886443
# ...

# %%
mydata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       205 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
# ...

# %%
sn.pairplot(mydata)

# %%
sn.boxplot(x='num-of-doors',y='highway-mpg',data=mydata)

# %%
plt.hist('length',data=mydata)
plt.xlabel("Length")
# Out:
# Text(0.5, 0, 'Length')

# %%
sn.distplot(mydata['wheel-base'])

# %%
mydata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       205 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
# ...

# %%
mydata.hist(by='engine-location',column='wheel-base')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f8a057a74c0>,
# ...
#       dtype=object)

# %%
corr=mydata.corr()
corr
# Out:
#                    symboling  wheel-base    length     width    height  \
# symboling           1.000000   -0.531954 -0.357612 -0.232919 -0.541038
# wheel-base         -0.531954    1.000000  0.874587  0.795144  0.589435
# length             -0.357612    0.874587  1.000000  0.841118  0.491029
# width              -0.232919    0.795144  0.841118  1.000000  0.279210
# height             -0.541038    0.589435  0.491029  0.279210  1.000000
# curb-weight        -0.227691    0.776386  0.877728  0.867032  0.295572
# engine-size        -0.105790    0.569329  0.683360  0.735433  0.067149
# compression-ratio  -0.178515    0.249786  0.158414  0.181129  0.261214
# city-mpg           -0.035823   -0.470414 -0.670909 -0.642704 -0.048640
# highway-mpg         0.034606   -0.544082 -0.704662 -0.677218 -0.107358
# price              -0.082391    0.584642  0.690628  0.751265  0.135486
#
#                    curb-weight  engine-size  compression-ratio  city-mpg  \
# ...

# %%
mydata["price"] = pd.to_numeric(mydata.price, errors='coerce')
sn.heatmap(corr,annot=True)

# %%
sn.pairplot(mydata)

# %%
plt.scatter(data=mydata,x="width",y="price")

# %%
sn.scatterplot(data=mydata,x="peak-rpm",y="price")

# %%
# Out:
# array([   3.85234394, -371.5511905 ,    3.27643283,  -85.94579   ,
#         714.91532808,  105.2395556 ,  230.22286203])

# %%
regr.intercept_
# Out:
# -40156.88960188924

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score

# Load the diabetes dataset
diabetes_X, diabetes_y = datasets.load_diabetes(return_X_y=True)

# Use only one feature
diabetes_X = diabetes_X[:, np.newaxis, 2]

# Split the data into training/testing sets
diabetes_X_train = diabetes_X[:-20]
diabetes_X_test = diabetes_X[-20:]

# Split the targets into training/testing sets
diabetes_y_train = diabetes_y[:-20]
diabetes_y_test = diabetes_y[-20:]

# Create linear regression object
regr = linear_model.LinearRegression()

# Train the model using the training sets
regr.fit(diabetes_X_train, diabetes_y_train)

# Make predictions using the testing set
diabetes_y_pred = regr.predict(diabetes_X_test)

# The coefficients
print('Coefficients: \n', regr.coef_)
# The mean squared error
print('Mean squared error: %.2f'
      % mean_squared_error(diabetes_y_test, diabetes_y_pred))
# The coefficient of determination: 1 is perfect prediction
print('Coefficient of determination: %.2f'
      % r2_score(diabetes_y_test, diabetes_y_pred))

# %%
import pandas as pd
mydata["price"] = pd.to_numeric(weather.Temp, errors='coerce')

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       205 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
# ...

# %%
from sklearn.metrics import mean_squared_error, r2_score
df = mydata.reset_index()
df.dropna(subset = ["price"], inplace=True)
from sklearn import linear_model
import pandas as pd
y=df['price']
x=df[['curb-weight','city-mpg','wheel-base','length','width','engine-size','highway-mpg']]
# Split the data into training/testing sets
df_x_train = x[:-20]
df_x_test = x[-20:]

# Split the targets into training/testing sets
df_y_train = y[:-20]
df_y_test = y[-20:]
regr=linear_model.LinearRegression()

df["price"] = pd.to_numeric(df.price, errors='coerce')


regr.fit(df_x_train,df_y_train)
# Make predictions using the testing set
df_pred_test = regr.predict(df_x_test)

# The coefficients
print('Coefficients: \n', regr.coef_)
# The mean squared error
print('Mean squared error: %.2f'
      % mean_squared_error(df_y_test, df_pred_test))
# The coefficient of determination: 1 is perfect prediction
print('Coefficient of determination: %.2f'
      % r2_score(df_y_test, df_pred_test))
# Out:
# Coefficients:
#  [   3.1812544  -426.79877805    9.44240487  -83.14931424  670.68750813
#   111.56108654  265.29014453]
# Mean squared error: 6431521.43
# Coefficient of determination: 0.68

# %%
mydata.cov()
# Out:
#                     symboling    wheel-base        length         width  \
# symboling            1.550789     -3.989099     -5.494240     -0.622229
# wheel-base          -3.989099     36.261782     64.975189     10.271615
# length              -5.494240     64.975189    152.208688     22.261035
# width               -0.622229     10.271615     22.261035      4.601900
# height              -1.646344      8.673144     14.802788      1.463579
# curb-weight       -147.636083   2434.296746   5638.336200    968.445072
# engine-size         -5.486035    142.766545    351.081549     65.697786
# compression-ratio   -0.883009      5.974562      7.762938      1.543367
# city-mpg            -0.291846    -18.532090    -54.150574     -9.019859
# highway-mpg          0.296772    -22.562324    -59.868075    -10.004421
# price             -821.604303  28185.470888  67629.882871  12546.527923
#
#                         height   curb-weight    engine-size  \
# ...

# %%
x.std()
# Out:
# curb-weight    517.296727
# city-mpg         6.423220
# wheel-base       6.066366
# length          12.322175
# width            2.101471
# engine-size     41.546834
# highway-mpg      6.815150
# dtype: float64

# %%
3.430271e+06+35046.538284+28185.470888+67629.882871+12546.527923+288023.656169-38166.449254
# Out:
# 3823536.626881

# %%
3823536.626881/592.571943
# Out:
# 6452.4429008968455

# %%
#Plot outputs
#plt.scatterplot(df_x_test, df_y_test,  color='black')
plt.plot(df_x_test, df_pred_test, color='blue', linewidth=3)

plt.show()

# %%
df_x_test
#regr.intercept_
# Out:
#      curb-weight  city-mpg  wheel-base  length  width  engine-size  \
# 185         2212        27        97.3   171.7   65.5          109
# 186         2275        27        97.3   171.7   65.5          109
# 187         2319        37        97.3   171.7   65.5           97
# 188         2300        26        97.3   171.7   65.5          109
# 189         2254        24        94.5   159.3   64.2          109
# 190         2221        24        94.5   165.7   64.0          109
# 191         2661        19       100.4   180.2   66.9          136
# 192         2579        33       100.4   180.2   66.9           97
# 193         2563        25       100.4   183.1   66.9          109
# 194         2912        23       104.3   188.8   67.2          141
# 195         3034        23       104.3   188.8   67.2          141
# 196         2935        24       104.3   188.8   67.2          141
# 197         3042        24       104.3   188.8   67.2          141
# ...

# %%
x=df[['curb-weight','city-mpg','wheel-base','length','width','engine-size','highway-mpg']]
# Split the data into training/testing sets
x
df_x_train = x[:-20]
df_x_test = x[-20:]
df_x_train
df_x_test
# Out:
#      curb-weight  city-mpg  wheel-base  length  width  engine-size  \
# 185         2212        27        97.3   171.7   65.5          109
# 186         2275        27        97.3   171.7   65.5          109
# 187         2319        37        97.3   171.7   65.5           97
# 188         2300        26        97.3   171.7   65.5          109
# 189         2254        24        94.5   159.3   64.2          109
# 190         2221        24        94.5   165.7   64.0          109
# 191         2661        19       100.4   180.2   66.9          136
# 192         2579        33       100.4   180.2   66.9           97
# 193         2563        25       100.4   183.1   66.9          109
# 194         2912        23       104.3   188.8   67.2          141
# 195         3034        23       104.3   188.8   67.2          141
# 196         2935        24       104.3   188.8   67.2          141
# 197         3042        24       104.3   188.8   67.2          141
# ...

# %%
df_pred_test
# Out:
# array([10077.12268538, 10277.54171233,  6933.11724295, 10253.29156123,
#        10297.39998392,  9526.12547608, 15540.6088204 ,  8667.74271545,
#        11271.80188504, 15773.82210138, 16161.9351377 , 15420.19217444,
#        15760.58639482, 15938.80878525, 16295.10927761, 17086.56458441,
#        18239.40218864, 21654.93778513, 16830.15486685, 18347.8272466 ])
